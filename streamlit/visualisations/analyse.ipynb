# %% [markdown]
# # Further Data Extraction
# ### Imports

# %%
import pandas as pd
import psycopg2

# %% [markdown]
# ### Connect to CSV file

# %%
def connect_to_db(host, dbname, user, password, port):
    connection = psycopg2.connect(
        host=host,
        database=dbname,
        user=user,
        password=password,
        port=port
    )
    return connection

# %%
df.info
# Out:
# <bound method DataFrame.info of                              utc_date item_type  \
# 0    2025-06-13 09:13:02.030556+00:00         a
# 1    2025-06-13 09:13:04.086976+00:00         t
# 2    2025-06-13 09:13:10.177388+00:00         p
# 3    2025-06-13 09:13:10.328224+00:00         a
# 4    2025-06-13 09:13:10.804261+00:00         p
# ..                                ...       ...
# 134  2025-06-13 09:15:56.211846+00:00         a
# 135  2025-06-13 09:15:56.283757+00:00         a
# 136  2025-06-13 09:15:56.329754+00:00         a
# 137  2025-06-13 09:15:56.342583+00:00         a
# 138  2025-06-13 09:15:57.240272+00:00         t
#
#                                      album_name  \
# 0                              Recreations E.P.
# 1                                           NaN
# 2                               Environments II
# 3                                         Birds
# 4                   Multiple Angled Distortions
# ..                                          ...
# 134                    Demons n Tokyo tha movie
# 135        High the lon35tarr mixtape 2016-2017
# 136      HI C CLOUD SURFER KOWABUNGA SWAG BITCH
# 137  C.BOOGIE/MUNNIE FETISH RENEGADE DEMON 2015
# 138                                      Exiles
#
#                        artist_name  \
# 0                         Ed Mahon
# 1                      marc monton
# 2       The Future Sound Of London
# 3                          Redeyes
# 4       THE FUTURE SOUND OF LONDON
# ..                             ...
# 134  DIAMONDS ON MY DIC X HIGH CEE
# 135                  yung hi c ^_^
# 136                       HIGH CEE
# 137                  yung hi c ^_^
# 138                   Async Figure
#
#                                      item_description  \
# 0                                    Recreations E.P.
# 1    Kool & The Gang - Celebration (Marc Monton Edit)
# 2                                            E2 VINYL
# 3                                               Birds
# 4            Multiple Angle Distortions - GREEN VINYL
# ..                                                ...
# 134                          Demons n Tokyo tha movie
# 135              High the lon35tarr mixtape 2016-2017
# 136            HI C CLOUD SURFER KOWABUNGA SWAG BITCH
# 137        C.BOOGIE/MUNNIE FETISH RENEGADE DEMON 2015
# 138                                     Quero Evangel
#
#                                              tag_names  sold_for release_date  \
# 0    ['electronic', 'house', 'indie disco', 'nu dis...      4.75   2025-06-03
# 1     ['electronic', 'house', 'tech house', 'minimal']      1.15   2023-01-18
# 2    ['electronic', 'ambient electronic', 'classical']     29.83   2025-06-13
# 3    ['drum & bass', 'drum&bass', 'electronic', 'el...     11.54   2025-06-13
# 4    ['electronic', 'ambient electronic', 'classical']     24.41   2025-05-06
# ..                                                 ...       ...          ...
# 134  ['experimental', 'trap', 'aesthetic', 'cashemu...      7.00   2019-01-10
# 135  ['experimental', 'trap', 'cashemusic', 'lofi',...     10.00   2019-06-11
# 136  ['experimental', 'trap', 'cashemusic', 'lofi',...      7.00   2017-01-01
# 137  ['experimental', 'trap', 'cashemusic', 'lofi',...     10.00   2015-01-01
# 138                                     ['electronic']      0.34   2024-02-15
#
#        country_name slug_type  \
# 0    United Kingdom         a
# 1       Netherlands         t
# 2    United Kingdom         a
# 3    United Kingdom         a
# 4    United Kingdom         a
# ..              ...       ...
# 134   United States         a
# 135   United States         a
# 136   United States         a
# 137   United States         a
# 138          Sweden         t
#
#                                                    url  \
# 0    https://edmahon.bandcamp.com/album/recreations...
# 1    https://marcmonton.bandcamp.com/track/kool-the...
# 2      https://fsol.bandcamp.com/album/environments-ii
# 3             https://redeyes.bandcamp.com/album/birds
# 4    https://fsol.bandcamp.com/album/multiple-angle...
# ..                                                 ...
# 134  https://yunghic.bandcamp.com/album/demons-n-to...
# 135  https://yunghic.bandcamp.com/album/high-the-lo...
# 136  https://yunghic.bandcamp.com/album/hi-c-cloud-...
# 137  https://yunghic.bandcamp.com/album/c-boogie-mu...
# 138  https://asyncfigure.bandcamp.com/track/quero-e...
#
#                                          art_url
# 0    https://f4.bcbits.com/img/a3846336120_7.jpg
# 1    https://f4.bcbits.com/img/a0418889168_7.jpg
# 2    https://f4.bcbits.com/img/0022866920_37.jpg
# 3    https://f4.bcbits.com/img/a4096793284_7.jpg
# 4    https://f4.bcbits.com/img/0039548065_37.jpg
# ..                                           ...
# 134  https://f4.bcbits.com/img/a2272391527_7.jpg
# 135  https://f4.bcbits.com/img/a2909746671_7.jpg
# 136  https://f4.bcbits.com/img/a4208048731_7.jpg
# 137  https://f4.bcbits.com/img/a3362157336_7.jpg
# 138  https://f4.bcbits.com/img/a0523817714_7.jpg
#
# [139 rows x 12 columns]>

# %%
df.nunique()
# Out:
# utc_date            139
# item_type             4
# album_name          109
# artist_name         129
# item_description    139
# tag_names           109
# sold_for             73
# release_date         98
# country_name         24
# slug_type             3
# url                 138
# art_url             139
# dtype: int64

# %% [markdown]
# ## Modelling
# Dummy models to understand the data, which can also be used in the dashboard later on...

# %%
import altair as alt
import pandas as pd
from vega_datasets import data

# Get cleaned, unique list of country names
highlighted_countries = pd.DataFrame({
    'name': df['country_name'].dropna().str.strip().replace({
        'Republic of Korea': 'South Korea',
        'United States': 'United States of America'
    }).unique()
})

# Chart base layers
sphere = alt.Chart(alt.sphere()).mark_geoshape(fill='black')
graticule = alt.Chart(alt.graticule()).mark_geoshape(
    stroke='grey', strokeWidth=0.5)

# World topo data
countries = alt.topo_feature(data.world_110m.url, 'countries')

# Map with highlights
highlighted_layer = alt.Chart(countries).transform_lookup(
    lookup='properties.name',
    from_=alt.LookupData(highlighted_countries, 'name')
).mark_geoshape(
    stroke='white',
    strokeWidth=0.5
).encode(
    color=alt.condition(
        'datum.name != null',
        alt.value('red'),
        alt.value('grey')
    ),
    tooltip='properties.name:N'
)

# Render map
alt.layer(
    sphere,
    graticule,
    highlighted_layer
).project(
    'naturalEarth1'
).properties(width=600, height=400).configure_view(stroke=None)
# Out:
# alt.LayerChart(...)

# %%
import altair as alt
from vega_datasets import data

# Data generators for the background
sphere = alt.sphere()
graticule = alt.graticule()

# Source of land data
source = alt.topo_feature(data.world_110m.url, 'countries')

# Layering and configuring the components
alt.layer(
    alt.Chart(sphere).mark_geoshape(fill='lightblue'),
    alt.Chart(graticule).mark_geoshape(stroke='white', strokeWidth=0.5),
    alt.Chart(source).mark_geoshape(fill='ForestGreen', stroke='black')
).project(
    'naturalEarth1'
).properties(width=600, height=400).configure_view(stroke=None)
# Out:
# alt.LayerChart(...)
